# %%
import pandas as pd

# %%
train_data = pd.read_csv(r"..\ubiquitination\feature_combine\train_win31_feature_combine.csv")

# %%
rf_importances = pd.read_csv(r"C:\Users\Li Xiaokang\Desktop\null_importance_result\train31_RF_actual_nonzero_imp_df.csv")

# %%
rf_importances
# Out:
#            feature    importance
# 0           PWM_18  1.333672e-02
# 1           PWM_20  1.122247e-02
# 2            PWM_5  9.090473e-03
# 3           PWM_19  8.402824e-03
# 4           PWM_11  8.273458e-03
# ...            ...           ...
# 15337   AA531_8816  2.735678e-07
# 15338  AA531_15731  1.758294e-07
# 15339   AA531_7196  1.484911e-07
# 15340   AA531_1748  1.360035e-07
# 15341  AA531_12756  1.301641e-07
#
# [15342 rows x 2 columns]

# %%
top_767 = rf_importances.iloc[:767, 0].tolist()
top_767
# Out:
# ['PWM_18',
#  'PWM_20',
#  'PWM_5',
#  'PWM_19',
#  'PWM_11',
#  'PWM_12',
#  'PWM_15',
#  'PWM_23',
#  'PWM_7',
#  'PWM_22',
#  'PWM_21',
#  'PWM_10',
#  'PWM_14',
#  'PWM_16',
#  'PWM_8',
#  'PWM_28',
#  'PWM_13',
#  'EAAC_195',
#  'PWM_25',
#  'EAAC_355',
#  'PWM_24',
#  'PWM_9',
#  'PWM_31',
#  'PWM_26',
#  'EAAC_315',
#  'EAAC_395',
#  'EAAC_135',
#  'EAAC_455',
#  'PWM_30',
#  'EAAC_175',
#  'EAAC_435',
#  'PWM_27',
#  'EAAC_215',
#  'EAAC_235',
#  'EAAC_375',
#  'PWM_1',
#  'CKSAAP_871',
#  'AA531_12584',
#  'EAAC_115',
#  'EAAC_475',
#  'EAAC_335',
#  'EAAC_495',
#  'AA531_11972',
#  'PWM_29',
#  'EAAC_275',
#  'AA531_6328',
#  'EAAC_155',
#  'EAAC_255',
#  'PWM_2',
#  'AA531_2131',
#  'PWM_3',
#  'AA531_12221',
#  'PWM_4',
#  'AA531_12525',
#  'CKSAAP_1443',
#  'AA531_12240',
#  'PSSM_202',
#  'PSSM_502',
#  'EAAC_75',
#  'EAAC_95',
#  'EAAC_295',
#  'PWM_6',
#  'AA531_13176',
#  'AA531_12237',
#  'AA531_12803',
#  'AA531_11636',
#  'AA531_14934',
#  'AA531_12223',
# ...

# %%
top_767.insert(0, 'label')

# %%
top_df = train_data[top_767]

# %%
top_df.to_csv(r"C:\Users\Li Xiaokang\Desktop\null_importance_result\win31_RF_filtered_0.05_train_rf_top767.csv", index=False)
