# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_excel("D:/study/paper/Citrullination/organ/feature_construction/PSSM.xlsx", sheet_name='neg',header=None)

# %%
df
# Out:
#           0         1         2         3         4         5         6    \
# 0   -0.054572  1.582576  0.491144 -0.054572 -1.146003  1.036860  1.036860
# 1   -0.223607 -0.223607  0.996067  3.028856 -1.036722  0.589509  1.402624
# 2   -0.207215  0.828858  0.310822  0.310822 -1.243287  2.901003  1.346894
# 3    3.369861 -0.177361 -0.886805 -0.886805  0.532083 -0.177361 -0.177361
# 4    0.536745 -0.927105 -0.927105 -0.927105  0.048795 -0.439155 -0.439155
# ..        ...       ...       ...       ...       ...       ...       ...
# 650  0.805189 -0.115027  0.805189  0.345081 -0.575135 -0.115027 -0.115027
# 651  0.805189 -0.115027  0.805189  0.345081 -0.575135 -0.115027 -0.115027
# 652 -0.068711  0.389360  0.389360  1.305502 -1.442923  1.305502  2.679714
# 653  0.022367  0.022367  0.917029  2.259023 -1.319627  0.917029  2.259023
# 654 -0.282552 -0.282552  1.021536  3.195016 -0.717249  0.586840  1.021536
#
#           7         8         9    ...       290       291       292  \
# ...

# %%
df.values.shape
# Out:
# (655, 300)

# %%
np.savetxt('D:/study/paper/Citrullination/organ/feature_construction/PSSM_neg.txt',df.values,delimiter=',')
